# %%
import os
import pandas as pd
import numpy as np
from google.colab import drive
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, Flatten, Dense, Concatenate, Dropout
from tensorflow.keras.preprocessing.image import load_img, img_to_array
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
import glob
import zipfile
import pickle
from PIL import Image
import uuid

# %%
# Mount Google Drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Define paths
zip_path = '/content/drive/MyDrive/image.zip'  # Update to your zip file path
extract_path = '/content/disaster_dataset'  # Temporary folder in Colab
csv_path = '/content/drive/My Drive/disaster_dataset.csv'

# Step 1: Unzip the dataset
def unzip_dataset(zip_path, extract_path):
    os.makedirs(extract_path, exist_ok=True)
    with zipfile.ZipFile(zip_path, 'r') as zip_ref:
        zip_ref.extractall(extract_path)
    print(f"Dataset unzipped to {extract_path}")
    # Find the folder containing disaster subfolders
    for root, dirs, _ in os.walk(extract_path):
        # Look for a folder with multiple subfolders (likely disaster types)
        subdirs = [d for d in dirs if os.path.isdir(os.path.join(root, d))]
        if len(subdirs) > 1:  # Assume folder with multiple subfolders is the right one
            dataset_path = root
            print(f"Found dataset root: {dataset_path} with subfolders: {subdirs}")
            return dataset_path
        # Special case: Check if 'image' folder contains subfolders
        if 'image' in dirs:
            image_path = os.path.join(root, 'image')
            image_subdirs = [d for d in os.listdir(image_path) if os.path.isdir(os.path.join(image_path, d))]
            if image_subdirs:
                print(f"Found dataset root: {image_path} with subfolders: {image_subdirs}")
                return image_path
    print(f"Warning: Could not find folder with disaster subfolders. Using root: {extract_path}")
    return extract_path

# Unzip the dataset
dataset_path = unzip_dataset(zip_path, extract_path)
# Out:
# Dataset unzipped to /content/disaster_dataset
# Found dataset root: /content/disaster_dataset/image with subfolders: ['wildefire', 'sinkhole', 'volcano', 'Hailstorm', 'Earthquake', 'Drought', 'landslideDisaster', 'Flood', 'locustwarn']

# %%
# Step 2: Generate CSV file from dataset
def generate_csv(dataset_path, csv_path):
    image_paths = []
    labels = []

    # Get list of disaster folders
    disaster_folders = [f for f in os.listdir(dataset_path) if os.path.isdir(os.path.join(dataset_path, f))]
    if not disaster_folders:
        raise ValueError(f"No disaster folders found in {dataset_path}. Check zip structure.")
    print(f"Disaster folders found: {disaster_folders}")

    for disaster in disaster_folders:
        # Get all files in the disaster folder recursively
        disaster_path = os.path.join(dataset_path, disaster)
        all_files = glob.glob(os.path.join(disaster_path, '**', '*'), recursive=True)

        # Verify each file as an image
        valid_images = []
        for file_path in all_files:
            if os.path.isdir(file_path):
                continue  # Skip directories
            try:
                with Image.open(file_path) as img:
                    img.verify()  # Check if file is a valid image
                # Reopen to check format
                with Image.open(file_path) as img:
                    if img.format in ['JPEG', 'PNG', 'BMP', 'GIF', 'TIFF', 'WEBP']:
                        valid_images.append(file_path)
                    else:
                        print(f"Skipping unsupported image format: {file_path} (format: {img.format})")
            except Exception as e:
                print(f"Skipping invalid file: {file_path} ({e})")

        image_paths.extend(valid_images)
        labels.extend([disaster] * len(valid_images))
        print(f"Found {len(valid_images)} valid images in {disaster}")

    # Create DataFrame
    df = pd.DataFrame({
        'image_path': image_paths,
        'label': labels
    })

    if df.empty:
        raise ValueError(f"No valid images found in {dataset_path}. Check folder structure or image files.")

    # Save to CSV
    df.to_csv(csv_path, index=False)
    print(f"CSV file saved at {csv_path} with {len(df)} images across {len(df['label'].unique())} disaster types")
    return df

# Generate CSV if it doesn't exist
if not os.path.exists(csv_path):
    df = generate_csv(dataset_path, csv_path)
else:
    df = pd.read_csv(csv_path)

# %%
# Step 3: Data preprocessing
disaster_types = df['label'].unique()
num_classes = len(disaster_types)
print(f"Disaster types: {disaster_types}")
print(f"Number of classes: {num_classes}")

from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()
df['label_encoded'] = label_encoder.fit_transform(df['label'])

from tensorflow.keras.preprocessing.image import load_img, img_to_array

# Function to load and preprocess images
def load_and_preprocess_image(image_path, target_size=(224, 224)):
    try:
        img = load_img(image_path, target_size=target_size)
        img_array = img_to_array(img) / 255.0
        return img_array
    except Exception as e:
        print(f"Error loading image {image_path}: {e}")
        return None

# Generator to load data in batches
def data_generator(df, batch_size, target_size=(224, 224), is_training=True):
    while True:
        df_sample = df.sample(frac=1).reset_index(drop=True) if is_training else df
        for start in range(0, len(df_sample), batch_size):
            end = min(start + batch_size, len(df_sample))
            batch_df = df_sample[start:end]

            images = []
            true_labels = []
            declared_labels = []

            for _, row in batch_df.iterrows():
                img = load_and_preprocess_image(row['image_path'], target_size)
                if img is None:
                    continue

                images.append(img)

                # One-hot encode true label
                true_label = np.zeros(num_classes, dtype=np.float32)
                true_label[row['label_encoded']] = 1
                true_labels.append(true_label)

                # Declared label: sometimes correct, sometimes incorrect (for training)
                if is_training and np.random.rand() > 0.5:
                    possible_labels = [i for i in range(num_classes) if i != row['label_encoded']]
                    declared_label_idx = np.random.choice(possible_labels)
                else:
                    declared_label_idx = row['label_encoded']

                declared_label = np.zeros(num_classes, dtype=np.float32)
                declared_label[declared_label_idx] = 1
                declared_labels.append(declared_label)

            if not images:
                continue

            images = np.array(images, dtype=np.float32)
            true_labels = np.array(true_labels, dtype=np.float32)
            declared_labels = np.array(declared_labels, dtype=np.float32)

            outputs = np.all(true_labels == declared_labels, axis=1).astype(np.float32)

            # Print every 10 batches only
            if start % (10 * batch_size) == 0:
                print(f"Yielding batch of {images.shape[0]} images")

            yield (images, declared_labels), outputs

# Create tf.data.Dataset
import tensorflow as tf

def create_dataset(df, batch_size, target_size=(224, 224), is_training=True):
    dataset = tf.data.Dataset.from_generator(
        lambda: data_generator(df, batch_size, target_size, is_training),
        output_signature=(
            (
                tf.TensorSpec(shape=(None, 224, 224, 3), dtype=tf.float32),
                tf.TensorSpec(shape=(None, num_classes), dtype=tf.float32)
            ),
            tf.TensorSpec(shape=(None,), dtype=tf.float32)
        )
    )

    dataset = dataset.shuffle(buffer_size=100).prefetch(tf.data.AUTOTUNE)
    return dataset
# Out:
# Disaster types: ['wildefire' 'sinkhole' 'volcano' 'Hailstorm' 'Earthquake' 'Drought'
#  'landslideDisaster' 'Flood' 'locustwarn']
# Number of classes: 9

# %%
# Step 4: Model definition
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, Flatten, Dense, Concatenate, Dropout

# Number of classes (already defined in Step 3)
# num_classes = len(disaster_types)  <-- already defined, no need to repeat

# Input 1: Image
image_input = Input(shape=(224, 224, 3), name="image_input")

# CNN feature extractor
x = Conv2D(32, (3, 3), activation='relu')(image_input)
x = MaxPooling2D(pool_size=(2, 2))(x)
x = Conv2D(64, (3, 3), activation='relu')(x)
x = MaxPooling2D(pool_size=(2, 2))(x)
x = Flatten()(x)

# Input 2: Declared disaster label (one-hot vector)
declared_label_input = Input(shape=(num_classes,), name="declared_label_input")

# Combine image features and declared label
merged = Concatenate()([x, declared_label_input])
merged = Dense(224, activation='relu')(merged)
merged = Dropout(0.3)(merged)

# Output: Binary prediction (1 = match, 0 = mismatch)
output = Dense(1, activation='sigmoid')(merged)

# Model
model = Model(inputs=[image_input, declared_label_input], outputs=output)

# Compile model
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Print model summary
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ image_input         │ (None, 224, 224,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 222, 222,  │        896 │ image_input[0][0] │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d       │ (None, 111, 111,  │          0 │ conv2d[0][0]      │
# │ (MaxPooling2D)      │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1 (Conv2D)   │ (None, 109, 109,  │     18,496 │ max_pooling2d[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_1     │ (None, 54, 54,    │          0 │ conv2d_1[0][0]    │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ flatten (Flatten)   │ (None, 186624)    │          0 │ max_pooling2d_1[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ declared_label_inp… │ (None, 9)         │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 186633)    │          0 │ flatten[0][0],    │
# │ (Concatenate)       │                   │            │ declared_label_i… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 224)       │ 41,806,016 │ concatenate[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 224)       │          0 │ dense[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 1)         │        225 │ dropout[0][0]     │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 41,825,633 (159.55 MB)
#  Trainable params: 41,825,633 (159.55 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Step 5: Split data and train
train_df, val_df = train_test_split(df, test_size=0.2, stratify=df['label'], random_state=42)

# Training parameters
batch_size = 32 if num_classes <= 20 else 16
epochs = 15
steps_per_epoch = len(train_df) // batch_size
validation_steps = len(val_df) // batch_size

# Create datasets
train_dataset = create_dataset(train_df, batch_size, is_training=True)
val_dataset = create_dataset(val_df, batch_size, is_training=False)

# Train the model
history = model.fit(
    train_dataset,
    steps_per_epoch=steps_per_epoch,
    epochs=epochs,
    validation_data=val_dataset,
    validation_steps=validation_steps
)
# Out:
# Epoch 1/15
# Yielding batch of 32 images
# Yielding batch of 32 images
# Yielding batch of 32 images
# Yielding batch of 32 images
# Yielding batch of 32 images
# Yielding batch of 32 images
# Yielding batch of 32 images
# Yielding batch of 32 images
# /usr/local/lib/python3.11/dist-packages/PIL/Image.py:1043: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# Yielding batch of 32 images
# Yielding batch of 32 images
# Yielding batch of 32 images
#  10/530 ━━━━━━━━━━━━━━━━━━━━ 32:09 4s/step - accuracy: 0.5195 - loss: 5.0451Yielding batch of 32 images
#  20/530 ━━━━━━━━━━━━━━━━━━━━ 31:52 4s/step - accuracy: 0.5134 - loss: 3.7935Yielding batch of 32 images
#  30/530 ━━━━━━━━━━━━━━━━━━━━ 30:39 4s/step - accuracy: 0.5191 - loss: 3.1265Yielding batch of 32 images
#  40/530 ━━━━━━━━━━━━━━━━━━━━ 29:35 4s/step - accuracy: 0.5246 - loss: 2.7143Yielding batch of 32 images
#  50/530 ━━━━━━━━━━━━━━━━━━━━ 29:15 4s/step - accuracy: 0.5300 - loss: 2.4321Yielding batch of 32 images
#  60/530 ━━━━━━━━━━━━━━━━━━━━ 28:32 4s/step - accuracy: 0.5371 - loss: 2.2253Yielding batch of 32 images
#  70/530 ━━━━━━━━━━━━━━━━━━━━ 28:03 4s/step - accuracy: 0.5437 - loss: 2.0664Yielding batch of 32 images
#  80/530 ━━━━━━━━━━━━━━━━━━━━ 27:33 4s/step - accuracy: 0.5493 - loss: 1.9401Yielding batch of 32 images
#  90/530 ━━━━━━━━━━━━━━━━━━━━ 26:58 4s/step - accuracy: 0.5542 - loss: 1.8369Yielding batch of 32 images
# 100/530 ━━━━━━━━━━━━━━━━━━━━ 26:17 4s/step - accuracy: 0.5586 - loss: 1.7508Yielding batch of 32 images
# 110/530 ━━━━━━━━━━━━━━━━━━━━ 25:43 4s/step - accuracy: 0.5623 - loss: 1.6778Yielding batch of 32 images
# 120/530 ━━━━━━━━━━━━━━━━━━━━ 25:06 4s/step - accuracy: 0.5657 - loss: 1.6148Yielding batch of 32 images
# 130/530 ━━━━━━━━━━━━━━━━━━━━ 24:31 4s/step - accuracy: 0.5687 - loss: 1.5600Yielding batch of 32 images
# 140/530 ━━━━━━━━━━━━━━━━━━━━ 23:51 4s/step - accuracy: 0.5714 - loss: 1.5117Yielding batch of 32 images
# 150/530 ━━━━━━━━━━━━━━━━━━━━ 23:12 4s/step - accuracy: 0.5739 - loss: 1.4689Yielding batch of 32 images
# 160/530 ━━━━━━━━━━━━━━━━━━━━ 22:38 4s/step - accuracy: 0.5761 - loss: 1.4306Yielding batch of 32 images
# 170/530 ━━━━━━━━━━━━━━━━━━━━ 21:57 4s/step - accuracy: 0.5780 - loss: 1.3960Yielding batch of 32 images
# 180/530 ━━━━━━━━━━━━━━━━━━━━ 21:22 4s/step - accuracy: 0.5798 - loss: 1.3648Yielding batch of 32 images
# 183/530 ━━━━━━━━━━━━━━━━━━━━ 21:10 4s/step - accuracy: 0.5803 - loss: 1.3560Error loading image /content/disaster_dataset/image/landslideDisaster/Image_58.jpg: broken data stream when reading image file
# 190/530 ━━━━━━━━━━━━━━━━━━━━ 20:45 4s/step - accuracy: 0.5815 - loss: 1.3363Yielding batch of 32 images
# 200/530 ━━━━━━━━━━━━━━━━━━━━ 20:08 4s/step - accuracy: 0.5829 - loss: 1.3103Yielding batch of 32 images
# 210/530 ━━━━━━━━━━━━━━━━━━━━ 19:32 4s/step - accuracy: 0.5843 - loss: 1.2864Yielding batch of 32 images
# 220/530 ━━━━━━━━━━━━━━━━━━━━ 18:54 4s/step - accuracy: 0.5855 - loss: 1.2643Yielding batch of 32 images
# 230/530 ━━━━━━━━━━━━━━━━━━━━ 18:19 4s/step - accuracy: 0.5867 - loss: 1.2438Yielding batch of 32 images
# 237/530 ━━━━━━━━━━━━━━━━━━━━ 17:54 4s/step - accuracy: 0.5876 - loss: 1.2303Error loading image /content/disaster_dataset/image/landslideDisaster/Image_79.jpg: image file is truncated (12 bytes not processed)
# 240/530 ━━━━━━━━━━━━━━━━━━━━ 17:43 4s/step - accuracy: 0.5879 - loss: 1.2248Yielding batch of 32 images
# 245/530 ━━━━━━━━━━━━━━━━━━━━ 17:26 4s/step - accuracy: 0.5884 - loss: 1.2158Error loading image /content/disaster_dataset/image/Flood/merged_images_flood effect in Nepal_Image_108.jpg: image file is truncated (2 bytes not processed)
# 250/530 ━━━━━━━━━━━━━━━━━━━━ 17:08 4s/step - accuracy: 0.5889 - loss: 1.2071Yielding batch of 32 images
# 259/530 ━━━━━━━━━━━━━━━━━━━━ 16:35 4s/step - accuracy: 0.5898 - loss: 1.1922Yielding batch of 32 images
# 269/530 ━━━━━━━━━━━━━━━━━━━━ 16:00 4s/step - accuracy: 0.5908 - loss: 1.1767Yielding batch of 32 images
# 279/530 ━━━━━━━━━━━━━━━━━━━━ 15:23 4s/step - accuracy: 0.5917 - loss: 1.1620Yielding batch of 32 images
# 289/530 ━━━━━━━━━━━━━━━━━━━━ 14:48 4s/step - accuracy: 0.5926 - loss: 1.1483Yielding batch of 32 images
# 299/530 ━━━━━━━━━━━━━━━━━━━━ 14:10 4s/step - accuracy: 0.5934 - loss: 1.1353Yielding batch of 32 images
# 309/530 ━━━━━━━━━━━━━━━━━━━━ 13:34 4s/step - accuracy: 0.5942 - loss: 1.1231Yielding batch of 32 images
# 469/530 ━━━━━━━━━━━━━━━━━━━━ 3:23 3s/step - accuracy: 0.7923 - loss: 0.4409Yielding batch of 32 images
# 479/530 ━━━━━━━━━━━━━━━━━━━━ 2:49 3s/step - accuracy: 0.7924 - loss: 0.4407Yielding batch of 32 images
# 489/530 ━━━━━━━━━━━━━━━━━━━━ 2:16 3s/step - accuracy: 0.7925 - loss: 0.4406Yielding batch of 32 images
# 499/530 ━━━━━━━━━━━━━━━━━━━━ 1:43 3s/step - accuracy: 0.7926 - loss: 0.4404Yielding batch of 32 images
# 509/530 ━━━━━━━━━━━━━━━━━━━━ 1:09 3s/step - accuracy: 0.7928 - loss: 0.4402Yielding batch of 32 images
# 519/530 ━━━━━━━━━━━━━━━━━━━━ 36s 3s/step - accuracy: 0.7929 - loss: 0.4400Yielding batch of 32 images
# 529/530 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step - accuracy: 0.7930 - loss: 0.4398Yielding batch of 32 images
# 530/530 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.7931 - loss: 0.4398Yielding batch of 32 images
# Yielding batch of 32 images
# Yielding batch of 32 images
# Yielding batch of 32 images
# Yielding batch of 32 images
# Yielding batch of 32 images
# Yielding batch of 32 images
# Yielding batch of 32 images
# Yielding batch of 32 images
# Yielding batch of 32 images
# Yielding batch of 32 images
# Yielding batch of 32 images
# Yielding batch of 32 images
# Yielding batch of 32 images
# Yielding batch of 32 images
# Yielding batch of 32 images
# Yielding batch of 32 images
# Yielding batch of 32 images
# Yielding batch of 32 images
# Yielding batch of 32 images
# Yielding batch of 32 images
# Yielding batch of 32 images
# Yielding batch of 32 images
# Yielding batch of 32 images
# 530/530 ━━━━━━━━━━━━━━━━━━━━ 2014s 4s/step - accuracy: 0.7931 - loss: 0.4397 - val_accuracy: 0.7814 - val_loss: 0.4632
# Epoch 7/15
# Yielding batch of 32 images
#   2/530 ━━━━━━━━━━━━━━━━━━━━ 30:29 3s/step - accuracy: 0.8906 - loss: 0.3340Error loading image /content/disaster_dataset/image/landslideDisaster/Image_79.jpg: image file is truncated (12 bytes not processed)
#   9/530 ━━━━━━━━━━━━━━━━━━━━ 31:08 4s/step - accuracy: 0.8449 - loss: 0.3819Yielding batch of 32 images
#  19/530 ━━━━━━━━━━━━━━━━━━━━ 30:37 4s/step - accuracy: 0.8346 - loss: 0.3887Yielding batch of 32 images
#  29/530 ━━━━━━━━━━━━━━━━━━━━ 29:58 4s/step - accuracy: 0.8294 - loss: 0.3934Yielding batch of 32 images
#  39/530 ━━━━━━━━━━━━━━━━━━━━ 29:12 4s/step - accuracy: 0.8241 - loss: 0.3994Yielding batch of 32 images
#  49/530 ━━━━━━━━━━━━━━━━━━━━ 28:38 4s/step - accuracy: 0.8212 - loss: 0.4042Yielding batch of 32 images
#  59/530 ━━━━━━━━━━━━━━━━━━━━ 28:02 4s/step - accuracy: 0.8193 - loss: 0.4066Yielding batch of 32 images
#  69/530 ━━━━━━━━━━━━━━━━━━━━ 27:35 4s/step - accuracy: 0.8184 - loss: 0.4071Yielding batch of 32 images
#  79/530 ━━━━━━━━━━━━━━━━━━━━ 26:55 4s/step - accuracy: 0.8174 - loss: 0.4073Yielding batch of 32 images
#  88/530 ━━━━━━━━━━━━━━━━━━━━ 26:14 4s/step - accuracy: 0.8164 - loss: 0.4077Error loading image /content/disaster_dataset/image/landslideDisaster/Image_58.jpg: broken data stream when reading image file
#  89/530 ━━━━━━━━━━━━━━━━━━━━ 26:18 4s/step - accuracy: 0.8163 - loss: 0.4078Yielding batch of 32 images
#  99/530 ━━━━━━━━━━━━━━━━━━━━ 25:38 4s/step - accuracy: 0.8150 - loss: 0.4086Yielding batch of 32 images
# 109/530 ━━━━━━━━━━━━━━━━━━━━ 25:06 4s/step - accuracy: 0.8138 - loss: 0.4095Yielding batch of 32 images
# 119/530 ━━━━━━━━━━━━━━━━━━━━ 24:31 4s/step - accuracy: 0.8130 - loss: 0.4099Yielding batch of 32 images
yielding batch of 32 images
# Yielding batch of 32 images
# Yielding batch of 32 images
# Yielding batch of 32 images
# Yielding batch of 32 images
# Yielding batch of 32 images
# Yielding batch of 32 images
# Yielding batch of 32 images
# Yielding batch of 32 images
# Yielding batch of 32 images
# Yielding batch of 32 images
# Yielding batch of 32 images
# Yielding batch of 32 images
# Yielding batch of 32 images
# Yielding batch of 32 images
# Yielding batch of 32 images
# Yielding batch of 32 images
# Yielding batch of 32 images
# Yielding batch of 32 images
# Yielding batch of 32 images
# Yielding batch of 32 images
# Yielding batch of 32 images
# Yielding batch of 32 images
# Yielding batch of 32 images
# 530/530 ━━━━━━━━━━━━━━━━━━━━ 2065s 4s/step - accuracy: 0.9038 - loss: 0.2440 - val_accuracy: 0.8044 - val_loss: 0.4391
# Epoch 14/15
# Yielding batch of 32 images
#   9/530 ━━━━━━━━━━━━━━━━━━━━ 27:40 3s/step - accuracy: 0.8928 - loss: 0.2680Yielding batch of 32 images
#  19/530 ━━━━━━━━━━━━━━━━━━━━ 28:35 3s/step - accuracy: 0.9071 - loss: 0.2535Yielding batch of 32 images
#  29/530 ━━━━━━━━━━━━━━━━━━━━ 28:13 3s/step - accuracy: 0.9118 - loss: 0.2492Yielding batch of 32 images
#  39/530 ━━━━━━━━━━━━━━━━━━━━ 28:14 3s/step - accuracy: 0.9119 - loss: 0.2492Yielding batch of 32 images
#  49/530 ━━━━━━━━━━━━━━━━━━━━ 27:43 3s/step - accuracy: 0.9119 - loss: 0.2475Yielding batch of 32 images
#  59/530 ━━━━━━━━━━━━━━━━━━━━ 26:59 3s/step - accuracy: 0.9124 - loss: 0.2453Yielding batch of 32 images
#  69/530 ━━━━━━━━━━━━━━━━━━━━ 26:27 3s/step - accuracy: 0.9127 - loss: 0.2436Yielding batch of 32 images
#  79/530 ━━━━━━━━━━━━━━━━━━━━ 25:48 3s/step - accuracy: 0.9126 - loss: 0.2425Yielding batch of 32 images
#  89/530 ━━━━━━━━━━━━━━━━━━━━ 25:15 3s/step - accuracy: 0.9127 - loss: 0.2412Yielding batch of 32 images
#  99/530 ━━━━━━━━━━━━━━━━━━━━ 24:32 3s/step - accuracy: 0.9131 - loss: 0.2396Yielding batch of 32 images
# 109/530 ━━━━━━━━━━━━━━━━━━━━ 24:01 3s/step - accuracy: 0.9134 - loss: 0.2380Yielding batch of 32 images
# 119/530 ━━━━━━━━━━━━━━━━━━━━ 23:30 3s/step - accuracy: 0.9134 - loss: 0.2368Yielding batch of 32 images
# 129/530 ━━━━━━━━━━━━━━━━━━━━ 22:53 3s/step - accuracy: 0.9134 - loss: 0.2359Yielding batch of 32 images
# 139/530 ━━━━━━━━━━━━━━━━━━━━ 22:28 3s/step - accuracy: 0.9135 - loss: 0.2349Yielding batch of 32 images
# 149/530 ━━━━━━━━━━━━━━━━━━━━ 21:52 3s/step - accuracy: 0.9136 - loss: 0.2341Yielding batch of 32 images
# 159/530 ━━━━━━━━━━━━━━━━━━━━ 21:23 3s/step - accuracy: 0.9137 - loss: 0.2333Yielding batch of 32 images
# 169/530 ━━━━━━━━━━━━━━━━━━━━ 20:44 3s/step - accuracy: 0.9139 - loss: 0.2325Yielding batch of 32 images
# 179/530 ━━━━━━━━━━━━━━━━━━━━ 20:11 3s/step - accuracy: 0.9141 - loss: 0.2317Yielding batch of 32 images
# 186/530 ━━━━━━━━━━━━━━━━━━━━ 19:47 3s/step - accuracy: 0.9142 - loss: 0.2312Error loading image /content/disaster_dataset/image/Flood/merged_images_flood effect in Nepal_Image_108.jpg: image file is truncated (2 bytes not processed)
# 189/530 ━━━━━━━━━━━━━━━━━━━━ 19:38 3s/step - accuracy: 0.9142 - loss: 0.2310Yielding batch of 32 images
# 199/530 ━━━━━━━━━━━━━━━━━━━━ 19:02 3s/step - accuracy: 0.9144 - loss: 0.2305Yielding batch of 32 images
# 209/530 ━━━━━━━━━━━━━━━━━━━━ 18:25 3s/step - accuracy: 0.9145 - loss: 0.2300Yielding batch of 32 images
# 212/530 ━━━━━━━━━━━━━━━━━━━━ 18:14 3s/step - accuracy: 0.9145 - loss: 0.2298Error loading image /content/disaster_dataset/image/landslideDisaster/Image_79.jpg: image file is truncated (12 bytes not processed)
# 219/530 ━━━━━━━━━━━━━━━━━━━━ 17:51 3s/step - accuracy: 0.9145 - loss: 0.2295Yielding batch of 32 images
# 229/530 ━━━━━━━━━━━━━━━━━━━━ 17:16 3s/step - accuracy: 0.9146 - loss: 0.2290Yielding batch of 32 images
# 239/530 ━━━━━━━━━━━━━━━━━━━━ 16:40 3s/step - accuracy: 0.9147 - loss: 0.2287Yielding batch of 32 images
# 249/530 ━━━━━━━━━━━━━━━━━━━━ 16:08 3s/step - accuracy: 0.9147 - loss: 0.2283Yielding batch of 32 images
# 259/530 ━━━━━━━━━━━━━━━━━━━━ 15:31 3s/step - accuracy: 0.9148 - loss: 0.2279Yielding batch of 32 images
# 269/530 ━━━━━━━━━━━━━━━━━━━━ 14:55 3s/step - accuracy: 0.9149 - loss: 0.2276Yielding batch of 32 images
# 279/530 ━━━━━━━━━━━━━━━━━━━━ 14:21 3s/step - accuracy: 0.9150 - loss: 0.2272Yielding batch of 32 images
# 289/530 ━━━━━━━━━━━━━━━━━━━━ 13:46 3s/step - accuracy: 0.9151 - loss: 0.2268Yielding batch of 32 images
# 299/530 ━━━━━━━━━━━━━━━━━━━━ 13:11 3s/step - accuracy: 0.9152 - loss: 0.2265Yielding batch of 32 images
# 309/530 ━━━━━━━━━━━━━━━━━━━━ 12:36 3s/step - accuracy: 0.9154 - loss: 0.2261Yielding batch of 32 images
# 319/530 ━━━━━━━━━━━━━━━━━━━━ 12:03 3s/step - accuracy: 0.9155 - loss: 0.2258Yielding batch of 32 images
# 329/530 ━━━━━━━━━━━━━━━━━━━━ 11:29 3s/step - accuracy: 0.9156 - loss: 0.2255Yielding batch of 32 images
# 339/530 ━━━━━━━━━━━━━━━━━━━━ 10:54 3s/step - accuracy: 0.9156 - loss: 0.2252Yielding batch of 32 images
# 349/530 ━━━━━━━━━━━━━━━━━━━━ 10:20 3s/step - accuracy: 0.9157 - loss: 0.2249Yielding batch of 32 images
# 359/530 ━━━━━━━━━━━━━━━━━━━━ 9:46 3s/step - accuracy: 0.9158 - loss: 0.2247Yielding batch of 32 images
# 369/530 ━━━━━━━━━━━━━━━━━━━━ 9:14 3s/step - accuracy: 0.9159 - loss: 0.2244Yielding batch of 32 images
# 379/530 ━━━━━━━━━━━━━━━━━━━━ 8:39 3s/step - accuracy: 0.9160 - loss: 0.2242Yielding batch of 32 images
# 389/530 ━━━━━━━━━━━━━━━━━━━━ 8:06 3s/step - accuracy: 0.9160 - loss: 0.2239Yielding batch of 32 images
# 399/530 ━━━━━━━━━━━━━━━━━━━━ 7:32 3s/step - accuracy: 0.9161 - loss: 0.2237Yielding batch of 32 images
# 409/530 ━━━━━━━━━━━━━━━━━━━━ 6:59 3s/step - accuracy: 0.9161 - loss: 0.2235Yielding batch of 32 images
# 419/530 ━━━━━━━━━━━━━━━━━━━━ 6:24 3s/step - accuracy: 0.9162 - loss: 0.2234Yielding batch of 32 images
# 429/530 ━━━━━━━━━━━━━━━━━━━━ 5:50 3s/step - accuracy: 0.9162 - loss: 0.2232Yielding batch of 32 images
# 439/530 ━━━━━━━━━━━━━━━━━━━━ 5:15 3s/step - accuracy: 0.9162 - loss: 0.2231Yielding batch of 32 images
# 449/530 ━━━━━━━━━━━━━━━━━━━━ 4:41 3s/step - accuracy: 0.9162 - loss: 0.2229Yielding batch of 32 images
# 459/530 ━━━━━━━━━━━━━━━━━━━━ 4:06 3s/step - accuracy: 0.9162 - loss: 0.2228Yielding batch of 32 images
# 469/530 ━━━━━━━━━━━━━━━━━━━━ 3:32 3s/step - accuracy: 0.9163 - loss: 0.2227Yielding batch of 32 images
# 479/530 ━━━━━━━━━━━━━━━━━━━━ 2:57 3s/step - accuracy: 0.9163 - loss: 0.2225Yielding batch of 32 images
# 489/530 ━━━━━━━━━━━━━━━━━━━━ 2:23 3s/step - accuracy: 0.9163 - loss: 0.2224Yielding batch of 32 images
# 499/530 ━━━━━━━━━━━━━━━━━━━━ 1:48 3s/step - accuracy: 0.9163 - loss: 0.2223Yielding batch of 32 images
# 509/530 ━━━━━━━━━━━━━━━━━━━━ 1:13 3s/step - accuracy: 0.9163 - loss: 0.2222Yielding batch of 32 images
# 515/530 ━━━━━━━━━━━━━━━━━━━━ 52s 3s/step - accuracy: 0.9164 - loss: 0.2221Error loading image /content/disaster_dataset/image/Flood/merged_images_flood effect in Nepal_Image_108.jpg: image file is truncated (2 bytes not processed)
# 519/530 ━━━━━━━━━━━━━━━━━━━━ 38s 3s/step - accuracy: 0.9164 - loss: 0.2221Yielding batch of 32 images
# 529/530 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step - accuracy: 0.9164 - loss: 0.2219Yielding batch of 32 images
# 530/530 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.9164 - loss: 0.2219Yielding batch of 32 images
# Yielding batch of 32 images
# Yielding batch of 32 images
# Yielding batch of 32 images
# Yielding batch of 32 images
# Yielding batch of 32 images
# Yielding batch of 32 images
# Yielding batch of 32 images
# Yielding batch of 32 images
# Yielding batch of 32 images
# Yielding batch of 32 images
# Yielding batch of 32 images
# Yielding batch of 32 images
# Yielding batch of 32 images
# Yielding batch of 32 images
# Yielding batch of 32 images
# Yielding batch of 32 images
# Yielding batch of 32 images
# Yielding batch of 32 images
# Yielding batch of 32 images
# Yielding batch of 32 images
# Yielding batch of 32 images
# Yielding batch of 32 images
# Yielding batch of 32 images
# 530/530 ━━━━━━━━━━━━━━━━━━━━ 2136s 4s/step - accuracy: 0.9164 - loss: 0.2219 - val_accuracy: 0.8118 - val_loss: 0.4374
# Epoch 15/15
# Yielding batch of 32 images
#   9/530 ━━━━━━━━━━━━━━━━━━━━ 33:59 4s/step - accuracy: 0.9318 - loss: 0.2349Yielding batch of 32 images
#  19/530 ━━━━━━━━━━━━━━━━━━━━ 32:49 4s/step - accuracy: 0.9336 - loss: 0.2204Yielding batch of 32 images
#  29/530 ━━━━━━━━━━━━━━━━━━━━ 31:59 4s/step - accuracy: 0.9337 - loss: 0.2157Yielding batch of 32 images
#  39/530 ━━━━━━━━━━━━━━━━━━━━ 31:36 4s/step - accuracy: 0.9321 - loss: 0.2154Yielding batch of 32 images
#  49/530 ━━━━━━━━━━━━━━━━━━━━ 30:42 4s/step - accuracy: 0.9315 - loss: 0.2142Yielding batch of 32 images
#  59/530 ━━━━━━━━━━━━━━━━━━━━ 30:06 4s/step - accuracy: 0.9306 - loss: 0.2134Yielding batch of 32 images
#  69/530 ━━━━━━━━━━━━━━━━━━━━ 29:24 4s/step - accuracy: 0.9296 - loss: 0.2131Yielding batch of 32 images
#  79/530 ━━━━━━━━━━━━━━━━━━━━ 28:45 4s/step - accuracy: 0.9288 - loss: 0.2130Yielding batch of 32 images
#  89/530 ━━━━━━━━━━━━━━━━━━━━ 28:20 4s/step - accuracy: 0.9284 - loss: 0.2128Yielding batch of 32 images
#  99/530 ━━━━━━━━━━━━━━━━━━━━ 27:47 4s/step - accuracy: 0.9281 - loss: 0.2130Yielding batch of 32 images
# 109/530 ━━━━━━━━━━━━━━━━━━━━ 27:03 4s/step - accuracy: 0.9277 - loss: 0.2131Yielding batch of 32 images
# 119/530 ━━━━━━━━━━━━━━━━━━━━ 26:33 4s/step - accuracy: 0.9275 - loss: 0.2131Yielding batch of 32 images
# 129/530 ━━━━━━━━━━━━━━━━━━━━ 25:46 4s/step - accuracy: 0.9273 - loss: 0.2129Yielding batch of 32 images
# 139/530 ━━━━━━━━━━━━━━━━━━━━ 25:09 4s/step - accuracy: 0.9271 - loss: 0.2126Yielding batch of 32 images
# 149/530 ━━━━━━━━━━━━━━━━━━━━ 24:32 4s/step - accuracy: 0.9270 - loss: 0.2122Yielding batch of 32 images
# 159/530 ━━━━━━━━━━━━━━━━━━━━ 23:51 4s/step - accuracy: 0.9269 - loss: 0.2116Yielding batch of 32 images
# 169/530 ━━━━━━━━━━━━━━━━━━━━ 23:13 4s/step - accuracy: 0.9268 - loss: 0.2111Yielding batch of 32 images
# 179/530 ━━━━━━━━━━━━━━━━━━━━ 22:31 4s/step - accuracy: 0.9267 - loss: 0.2107Yielding batch of 32 images
# 189/530 ━━━━━━━━━━━━━━━━━━━━ 21:49 4s/step - accuracy: 0.9266 - loss: 0.2103Yielding batch of 32 images
# 199/530 ━━━━━━━━━━━━━━━━━━━━ 21:06 4s/step - accuracy: 0.9265 - loss: 0.2101Yielding batch of 32 images
# 204/530 ━━━━━━━━━━━━━━━━━━━━ 20:47 4s/step - accuracy: 0.9265 - loss: 0.2100Error loading image /content/disaster_dataset/image/landslideDisaster/Image_58.jpg: broken data stream when reading image file
# 209/530 ━━━━━━━━━━━━━━━━━━━━ 20:27 4s/step - accuracy: 0.9264 - loss: 0.2099Yielding batch of 32 images
# 219/530 ━━━━━━━━━━━━━━━━━━━━ 19:49 4s/step - accuracy: 0.9263 - loss: 0.2097Yielding batch of 32 images
# 229/530 ━━━━━━━━━━━━━━━━━━━━ 19:10 4s/step - accuracy: 0.9262 - loss: 0.2096Yielding batch of 32 images
# 239/530 ━━━━━━━━━━━━━━━━━━━━ 18:32 4s/step - accuracy: 0.9262 - loss: 0.2094Yielding batch of 32 images
# 249/530 ━━━━━━━━━━━━━━━━━━━━ 17:52 4s/step - accuracy: 0.9261 - loss: 0.2093Yielding batch of 32 images
# 259/530 ━━━━━━━━━━━━━━━━━━━━ 17:14 4s/step - accuracy: 0.9260 - loss: 0.2091Yielding batch of 32 images
# 269/530 ━━━━━━━━━━━━━━━━━━━━ 16:35 4s/step - accuracy: 0.9260 - loss: 0.2089Yielding batch of 32 images
# 279/530 ━━━━━━━━━━━━━━━━━━━━ 15:57 4s/step - accuracy: 0.9259 - loss: 0.2088Yielding batch of 32 images
# 289/530 ━━━━━━━━━━━━━━━━━━━━ 15:20 4s/step - accuracy: 0.9258 - loss: 0.2087Yielding batch of 32 images
# 299/530 ━━━━━━━━━━━━━━━━━━━━ 14:41 4s/step - accuracy: 0.9257 - loss: 0.2087Yielding batch of 32 images
# 309/530 ━━━━━━━━━━━━━━━━━━━━ 14:04 4s/step - accuracy: 0.9257 - loss: 0.2087Yielding batch of 32 images
# 319/530 ━━━━━━━━━━━━━━━━━━━━ 13:24 4s/step - accuracy: 0.9256 - loss: 0.2087Yielding batch of 32 images
# 329/530 ━━━━━━━━━━━━━━━━━━━━ 12:47 4s/step - accuracy: 0.9255 - loss: 0.2087Yielding batch of 32 images
# 339/530 ━━━━━━━━━━━━━━━━━━━━ 12:09 4s/step - accuracy: 0.9255 - loss: 0.2087Yielding batch of 32 images
# 349/530 ━━━━━━━━━━━━━━━━━━━━ 11:31 4s/step - accuracy: 0.9254 - loss: 0.2087Yielding batch of 32 images
# 359/530 ━━━━━━━━━━━━━━━━━━━━ 10:53 4s/step - accuracy: 0.9254 - loss: 0.2086Yielding batch of 32 images
# 369/530 ━━━━━━━━━━━━━━━━━━━━ 10:15 4s/step - accuracy: 0.9253 - loss: 0.2086Yielding batch of 32 images
# 379/530 ━━━━━━━━━━━━━━━━━━━━ 9:36 4s/step - accuracy: 0.9253 - loss: 0.2086Yielding batch of 32 images
# 389/530 ━━━━━━━━━━━━━━━━━━━━ 8:57 4s/step - accuracy: 0.9252 - loss: 0.2085Yielding batch of 32 images
# 399/530 ━━━━━━━━━━━━━━━━━━━━ 8:18 4s/step - accuracy: 0.9252 - loss: 0.2084Yielding batch of 32 images
# 409/530 ━━━━━━━━━━━━━━━━━━━━ 7:39 4s/step - accuracy: 0.9252 - loss: 0.2083Yielding batch of 32 images
# 419/530 ━━━━━━━━━━━━━━━━━━━━ 7:01 4s/step - accuracy: 0.9252 - loss: 0.2082Yielding batch of 32 images
# 428/530 ━━━━━━━━━━━━━━━━━━━━ 6:26 4s/step - accuracy: 0.9252 - loss: 0.2081Error loading image /content/disaster_dataset/image/landslideDisaster/Image_79.jpg: image file is truncated (12 bytes not processed)
# 429/530 ━━━━━━━━━━━━━━━━━━━━ 6:22 4s/step - accuracy: 0.9252 - loss: 0.2081Yielding batch of 32 images
# 439/530 ━━━━━━━━━━━━━━━━━━━━ 5:44 4s/step - accuracy: 0.9252 - loss: 0.2080Yielding batch of 32 images
# 449/530 ━━━━━━━━━━━━━━━━━━━━ 5:05 4s/step - accuracy: 0.9252 - loss: 0.2079Yielding batch of 32 images
# 459/530 ━━━━━━━━━━━━━━━━━━━━ 4:28 4s/step - accuracy: 0.9252 - loss: 0.2078Yielding batch of 32 images
# 469/530 ━━━━━━━━━━━━━━━━━━━━ 3:50 4s/step - accuracy: 0.9252 - loss: 0.2077Yielding batch of 32 images
# 479/530 ━━━━━━━━━━━━━━━━━━━━ 3:12 4s/step - accuracy: 0.9252 - loss: 0.2076Yielding batch of 32 images
# 489/530 ━━━━━━━━━━━━━━━━━━━━ 2:34 4s/step - accuracy: 0.9252 - loss: 0.2076Yielding batch of 32 images
# 499/530 ━━━━━━━━━━━━━━━━━━━━ 1:56 4s/step - accuracy: 0.9252 - loss: 0.2075Error loading image /content/disaster_dataset/image/landslideDisaster/Image_79.jpg: image file is truncated (12 bytes not processed)
# Yielding batch of 31 images
# 509/530 ━━━━━━━━━━━━━━━━━━━━ 1:18 4s/step - accuracy: 0.9252 - loss: 0.2075Yielding batch of 32 images
# 519/530 ━━━━━━━━━━━━━━━━━━━━ 41s 4s/step - accuracy: 0.9252 - loss: 0.2074Yielding batch of 32 images
# 525/530 ━━━━━━━━━━━━━━━━━━━━ 18s 4s/step - accuracy: 0.9252 - loss: 0.2074Error loading image /content/disaster_dataset/image/landslideDisaster/Image_58.jpg: broken data stream when reading image file
# 529/530 ━━━━━━━━━━━━━━━━━━━━ 3s 4s/step - accuracy: 0.9252 - loss: 0.2073Yielding batch of 32 images
# 530/530 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.9252 - loss: 0.2073Yielding batch of 32 images
# Yielding batch of 32 images
# Yielding batch of 32 images
# Yielding batch of 32 images
# Yielding batch of 32 images
# Yielding batch of 32 images
# Yielding batch of 32 images
# Yielding batch of 32 images
# Yielding batch of 32 images
# Yielding batch of 32 images
# Yielding batch of 32 images
# Yielding batch of 32 images
# Yielding batch of 32 images
# Yielding batch of 32 images
# Yielding batch of 32 images
# Yielding batch of 32 images
# Yielding batch of 32 images
# Yielding batch of 32 images
# Yielding batch of 32 images
# Yielding batch of 32 images
# Yielding batch of 32 images
# Yielding batch of 32 images
# Yielding batch of 32 images
# Yielding batch of 32 images
# 530/530 ━━━━━━━━━━━━━━━━━━━━ 2219s 4s/step - accuracy: 0.9252 - loss: 0.2073 - val_accuracy: 0.8301 - val_loss: 0.4011
# Yielding batch of 32 images

# %%
import numpy as np
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix

# Step 6: Evaluate model accuracy with metrics

# Collect predictions and true labels
y_true = []
y_pred = []

for (images, declared_labels), outputs in val_dataset.take(10):  # Adjust take(n) as needed
    predictions = model.predict([images, declared_labels])
    predicted_labels = (predictions > 0.5).astype(int)

    y_true.extend(outputs.numpy().astype(int))
    y_pred.extend(predicted_labels.flatten().astype(int))

# Convert to numpy arrays
y_true = np.array(y_true)
y_pred = np.array(y_pred)

# Accuracy & metrics
acc = accuracy_score(y_true, y_pred)
prec = precision_score(y_true, y_pred, zero_division=0)
rec = recall_score(y_true, y_pred, zero_division=0)
f1 = f1_score(y_true, y_pred, zero_division=0)
cm = confusion_matrix(y_true, y_pred)

# Display results
print(f"✅ Accuracy:  {acc:.4f}")
print(f"✅ Precision: {prec:.4f}")
print(f"✅ Recall:    {rec:.4f}")
print(f"✅ F1 Score:  {f1:.4f}")
print("\n📊 Confusion Matrix:")
print(cm)
# Out:
# Yielding batch of 32 images
# Yielding batch of 32 images
# Yielding batch of 32 images
# Yielding batch of 32 images
# Yielding batch of 32 images
# Yielding batch of 32 images
# Yielding batch of 32 images
# Yielding batch of 32 images
# Yielding batch of 32 images
# Yielding batch of 32 images
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Yielding batch of 32 images
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 951ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 868ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 885ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 807ms/step
# ✅ Accuracy:  0.8344
# ✅ Precision: 1.0000
# ✅ Recall:    0.8344
# ✅ F1 Score:  0.9097
#
# 📊 Confusion Matrix:
# [[  0   0]
#  [ 53 267]]

# %%
# Save model to a .keras file
model.save("disaster_match_modelqwe.keras")
print("✅ Model saved to disaster_match_model.keras")
# Out:
# ✅ Model saved to disaster_match_model.keras

# %%
from tensorflow.keras.models import load_model

model = load_model("disaster_match_model.keras")
print("✅ Model loaded.")
# Out:
# ✅ Model loaded.
# /usr/local/lib/python3.11/dist-packages/keras/src/saving/saving_lib.py:757: UserWarning: Skipping variable loading for optimizer 'rmsprop', because it has 10 variables whereas the saved optimizer has 2 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))

# %%
# Replace with your actual image path
image_path = "/content/disaster_dataset/image/Earthquake/1 (1).PNG"
declared_label = "Earthquake"

# Preprocess image
img = load_img(image_path, target_size=(128, 128))
img_array = img_to_array(img) / 255.0
img_array = np.expand_dims(img_array, axis=0)  # shape: (1, 128, 128, 3)

# Encode declared label
declared_idx = label_encoder.transform([declared_label])[0]
declared_one_hot = np.zeros((1, num_classes))
declared_one_hot[0, declared_idx] = 1

# Predict
prediction = model.predict([img_array, declared_one_hot])[0][0]
is_match = prediction > 0.5

# Output
print(f"Declared: {declared_label}")
print(f"✅ Match: {is_match} (Confidence: {prediction:.2f})")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 258ms/step
# Declared: Earthquake
# ✅ Match: True (Confidence: 0.93)
